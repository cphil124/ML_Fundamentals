# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv

# %%
ages_x = [x for x in range(25,36)]
dev_y = [38496, 42000, 46752, 49320, 53200, 56000, 
         62316, 64928, 67317, 68748, 73752]
py_dev_y = [45372, 48876, 53850, 57287, 63016,
           65998, 70003, 70000, 71496, 75370, 83640]
js_dev_y = [37810, 43515, 46823, 49293, 53437,
           56373, 62375, 66674, 68745, 68746, 74583]
plt.title('Median Salary(USD) by Age')
plt.xlabel('Age')
plt.ylabel('Median Salary')

plt.style.use('fivethirtyeight')
# plt.xkcd()

plt.plot(ages_x, dev_y
         ,color = 'b'
         ,marker='o'
         ,label = 'All Devs'
         ,linewidth=3
        )
plt.plot(ages_x, py_dev_y
#         ,color = 'k'
         ,linestyle='--'
#          ,marker='.'
         ,label = 'Python'
        )
plt.plot(ages_x, js_dev_y
#          ,color='#5a7d9b'
         ,label = 'Javascript'

)
plt.legend(
#      ['All Devs', 'Python']   # Equivalent of adding 'label' params in plt.plot. Doing it with 
                                # plt.legend requires entering labels in the order they were added.
                                # Better to add in the plt.plot functions, as it doesn't require refactorin
)
plt.grid(True)
print(plt.style.available)
plt.tight_layout()
plt.savefig('plot.png')
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
# Superimposing line charts on top of a bar-chart
plt.bar(ages_x, dev_y
#          ,color = 'b'
#          ,marker='o'
         ,label = 'All Devs'
#          ,linewidth=3
        )
plt.plot(ages_x, py_dev_y
#         ,color = 'k'
         ,linestyle='--'
#          ,marker='.'
         ,label = 'Python'
        )
plt.plot(ages_x, js_dev_y
#          ,color='#5a7d9b'
         ,label = 'Javascript'
)

# %%
# Plotting multiple bar charts side-by-side
x_indexes = np.arange(len(ages_x)) # Changing indices for x-axis to help with offsetting
width = 0.25 # width of bars in chart, and width of offset
plt.xticks(ticks=x_indexes, labels=ages_x)
plt.bar(x_indexes+width, dev_y, width=width, label = 'All Devs')
plt.bar(x_indexes, py_dev_y, width=width, linestyle='--', label = 'Python')
plt.bar(x_indexes-width, js_dev_y, width=width, label = 'Javascript')
plt.xlabel('Ages')
plt.ylabel('Income')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Practice from reading in data from a CSV
data = pd.read_csv('housing\\housing.csv')
print(data.head())
print(data.describe())
age = data['housing_median_age']
inc = data['median_income']
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#           longitude      latitude  housing_median_age   total_rooms  \
# ...

# %%
x = pd.cut(age,[15,20,25,30,35,40,45,50,55], include_lowest=True)
print('X is ',type(x))
print(x)
ax = x.value_counts(sort=False).plot.bar(rot=0,color='b',figsize=(12,10))
# ax.set_xticklabels([c[1:-1].replace(","," to ") for c in x.cat.categories.right()]])
# Out:
# X is  <class 'pandas.core.series.Series'>
# 0          (40.0, 45.0]
# 1          (20.0, 25.0]
# 2          (50.0, 55.0]
# 3          (50.0, 55.0]
# 4          (50.0, 55.0]
# 5          (50.0, 55.0]
# 6          (50.0, 55.0]
# 7          (50.0, 55.0]
# 8          (40.0, 45.0]
# 9          (50.0, 55.0]
# 10         (50.0, 55.0]
# 11         (50.0, 55.0]
# 12         (50.0, 55.0]
# 13         (50.0, 55.0]
# 14         (50.0, 55.0]
# 15         (45.0, 50.0]
# 16         (50.0, 55.0]
# 17         (50.0, 55.0]
# 18         (45.0, 50.0]
# 19         (50.0, 55.0]
# 20         (35.0, 40.0]
# 21         (40.0, 45.0]
# 22         (50.0, 55.0]
# 23         (50.0, 55.0]
# 24         (50.0, 55.0]
# 25         (40.0, 45.0]
# 26         (45.0, 50.0]
# 27         (50.0, 55.0]
# 28         (45.0, 50.0]
# 29         (50.0, 55.0]
#               ...
# 20610      (25.0, 30.0]
# 20611      (25.0, 30.0]
# 20612      (25.0, 30.0]
# 20613      (30.0, 35.0]
# 20614      (25.0, 30.0]
# 20615      (20.0, 25.0]
# ...

# %%
def bin_column(col, cut_points, labels=None):
    minval = col.min()
    maxval = col.max()
    
    break_points = [minval] + cut_points + [maxval]
    
    if not labels:
        labels = range(len(cut_points)+1)
        
    colBin = pd.cut(col, bins=break_points, labels=labels, include_lowest=True)
    return colBin

income = bin_column(inc, [x for x in np.arange(0.5, 15, 0.5)])
print(income)
# plt.hist(x, income)
# Out:
# 0        16
# 1        16
# 2        14
# 3        11
# 4         7
# 5         8
# 6         7
# 7         6
# 8         4
# 9         7
# 10        6
# 11        6
# 12        6
# 13        5
# 14        3
# 15        4
# 16        5
# 17        4
# 18        3
# 19        5
# 20        2
# 21        3
# 22        3
# 23        4
# 24        5
# 25        4
# 26        4
# 27        3
# 28        3
# 29        3
#          ..
# 20610     2
# 20611     2
# 20612     2
# 20613     2
# 20614     4
# 20615     4
# 20616     4
# 20617     6
# 20618     4
# 20619     5
# 20620     9
# 20621     4
# 20622     4
# 20623     5
# 20624     6
# 20625     8
# 20626     4
# 20627     5
# 20628     5
# 20629     4
# 20630     7
# 20631     7
# 20632     6
# 20633     5
# 20634     7
# 20635     3
# 20636     5
# 20637     3
# 20638     3
# 20639     4
# Name: median_income, Length: 20640, dtype: category
# Categories (30, int64): [0 < 1 < 2 < 3 ... 26 < 27 < 28 < 29]

# %%
from itertools import count
import random
from matplotlib.animation import FuncAnimation



x_vals = []
y_vals = []

index = count()

def animate(i):
    x_vals.append(next(index))
    y_vals.append(random.randint(0,5))
    plt.cla()
    plt.plot(x_vals, y_vals)
    
ani = FuncAnimation(plt.gcf(), animate, interval=1000)

# %%
plt.style.use('seaborn')

fig, ax = plt.subplots()
ax.plot(x_vals, y_vals)
